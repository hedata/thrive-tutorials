# %% [markdown]
# We got the whole [R Cookbook](http://www.cookbook-r.com/) as reuseable Notebooks
#
# # Learning to Code
# * [Indexing into a dataframe](https://notebook.thrive.to/tutorial/45.ipynb)
# * [Getting a subset of a data structure](https://notebook.thrive.to/tutorial/46.ipynb)
# * [Vectors](https://notebook.thrive.to/tutorial/47.ipynb)
# * [Variables](https://notebook.thrive.to/tutorial/48.ipynb)
# * [Working with NULL  NA and NaN](https://notebook.thrive.to/tutorial/49.ipynb)
# * [Generating random numbers](https://notebook.thrive.to/tutorial/50.ipynb)
# * [Generating repeatable sequences of random numbers](https://notebook.thrive.to/tutorial/51.ipynb)
# * [Saving the state of the random number generator](https://notebook.thrive.to/tutorial/52.ipynb)
# * [Rounding numbers](https://notebook.thrive.to/tutorial/53.ipynb)
# * [Comparing floating point numbers](https://notebook.thrive.to/tutorial/54.ipynb)
# * [Creating strings from variables](https://notebook.thrive.to/tutorial/55.ipynb)
# * [Creating a formula from a string](https://notebook.thrive.to/tutorial/56.ipynb)
#
# # Data Cleaning
# * [Loading data from a file](https://notebook.thrive.to/tutorial/94.ipynb)
# * [Sorting](https://notebook.thrive.to/tutorial/99.ipynb)
# * [Randomizing order](https://notebook.thrive.to/tutorial/100.ipynb)
# * [Converting between vector types](https://notebook.thrive.to/tutorial/101.ipynb)
# * [Finding and removing duplicate records](https://notebook.thrive.to/tutorial/102.ipynb)
# * [Comparing vectors or factors with NA](https://notebook.thrive.to/tutorial/103.ipynb)
# * [Recoding data](https://notebook.thrive.to/tutorial/104.ipynb)
# * [Mapping vector values](https://notebook.thrive.to/tutorial/105.ipynb)
# * [Renaming levels of a factor](https://notebook.thrive.to/tutorial/106.ipynb)
# * [Re-computing the levels of factor](https://notebook.thrive.to/tutorial/107.ipynb)
# * [Changing the order of levels of a factor](https://notebook.thrive.to/tutorial/108.ipynb)
# * [Renaming columns in a data frame](https://notebook.thrive.to/tutorial/109.ipynb)
# * [Adding and removing columns from a data frame](https://notebook.thrive.to/tutorial/110.ipynb)
# * [Reordering the columns in a data frame](https://notebook.thrive.to/tutorial/111.ipynb)
# * [Merging data frames](https://notebook.thrive.to/tutorial/112.ipynb)
# * [Comparing data frames](https://notebook.thrive.to/tutorial/113.ipynb)
# * [Re-computing the levels of all factor columns in a data frame](https://notebook.thrive.to/tutorial/114.ipynb)
# * [Converting data between wide and long format](https://notebook.thrive.to/tutorial/115.ipynb)
# * [Summarizing data](https://notebook.thrive.to/tutorial/116.ipynb)
# * [Converting between data frames and contingency tables](https://notebook.thrive.to/tutorial/117.ipynb)
# * [Calculating a moving average](https://notebook.thrive.to/tutorial/118.ipynb)
# * [Averaging a sequence in blocks](https://notebook.thrive.to/tutorial/119.ipynb)
# * [Finding sequences of identical values](https://notebook.thrive.to/tutorial/120.ipynb)
# * [Filling in NAs with last non-NA value](https://notebook.thrive.to/tutorial/121.ipynb)
#
# # Visualizations
# * [Bar and line graphs (ggplot2)](https://notebook.thrive.to/tutorial/129.ipynb)
# * [Plotting means and error bars (ggplot2)](https://notebook.thrive.to/tutorial/130.ipynb)
# * [Plotting distributions (ggplot2)](https://notebook.thrive.to/tutorial/131.ipynb)
# * [Scatterplots (ggplot2)](https://notebook.thrive.to/tutorial/132.ipynb)
# * [Titles (ggplot2)](https://notebook.thrive.to/tutorial/133.ipynb)
# * [Axes (ggplot2)](https://notebook.thrive.to/tutorial/134.ipynb)
# * [Legends (ggplot2)](https://notebook.thrive.to/tutorial/135.ipynb)
# * [Lines (ggplot2)](https://notebook.thrive.to/tutorial/136.ipynb)
# * [Facets (ggplot2)](https://notebook.thrive.to/tutorial/137.ipynb)
# * [Multiple graphs on one page (ggplot2)](https://notebook.thrive.to/tutorial/138.ipynb)
# * [Colors (ggplot2)](https://notebook.thrive.to/tutorial/139.ipynb)
# * [Shapes and line types](https://notebook.thrive.to/tutorial/141.ipynb)
# * [Histogram and density plot](https://notebook.thrive.to/tutorial/143.ipynb)
# * [Scatterplot](https://notebook.thrive.to/tutorial/144.ipynb)
# * [Box plot](https://notebook.thrive.to/tutorial/145.ipynb)
# * [Q-Q plot](https://notebook.thrive.to/tutorial/146.ipynb)
# * [Correlation matrix](https://notebook.thrive.to/tutorial/147.ipynb)
#
#
# # Data Sciene & Statistics
# * [Extracting components from a formula](https://notebook.thrive.to/tutorial/93.ipynb)
# * [Regression and correlation](https://notebook.thrive.to/tutorial/122.ipynb)
# * [t-test](https://notebook.thrive.to/tutorial/123.ipynb)
# * [Frequency tests](https://notebook.thrive.to/tutorial/124.ipynb)
# * [ANOVA](https://notebook.thrive.to/tutorial/125.ipynb)
# * [Logistic regression](https://notebook.thrive.to/tutorial/126.ipynb)
# * [Homogeneity of variance](https://notebook.thrive.to/tutorial/127.ipynb)
# * [Inter-rater reliability](https://notebook.thrive.to/tutorial/128.ipynb)
